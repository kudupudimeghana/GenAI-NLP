# %% [markdown]
# <a href="https://colab.research.google.com/github/kudupudimeghana/GenAI-NLP/blob/main/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')   # important in your environment
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

text = "The cats were running faster than dogs."
tokens = word_tokenize(text)

lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens]

print(f"Original Text: {text}")
print(f"Lemmatized Words: {lemmatized_words}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Original Text: The cats were running faster than dogs.
# Lemmatized Words: ['The', 'cat', 'were', 'running', 'faster', 'than', 'dog', '.']

# %% [markdown]
# Word Frequency Counter

# %%
import nltk
from collections import Counter
from nltk.tokenize import word_tokenize

nltk.download('punkt_tab')
nltk.download('punkt')

text = "NLP is fun.NLP is powerful.Learning NLP is useful."

tokens = word_tokenize(text.lower())
word_count = Counter(tokens)

print("Tokens:", tokens)
print("Word Count:", word_count)
print("Most common:", word_count.most_common(3))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# Tokens: ['nlp', 'is', 'fun.nlp', 'is', 'powerful.learning', 'nlp', 'is', 'useful', '.']
# Word Count: Counter({'is': 3, 'nlp': 2, 'fun.nlp': 1, 'powerful.learning': 1, 'useful': 1, '.': 1})
# Most common: [('is', 3), ('nlp', 2), ('fun.nlp', 1)]
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Sentiment analysis

# %%
from textblob import TextBlob
text=input("Enter a sentence:")
analysis=TextBlob(text)
if analysis.sentiment.polarity > 0:
    print("Positive")
elif analysis.sentiment.polarity < 0:
    print("Negative")
else:
    print("Neutral")
# Out:
# Enter a sentence:you are a bad girl
# Negative

# %% [markdown]
# Named entity recognition

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

text = "Elon Musk founded SpaceX in the United States."
doc = nlp(text)

for ent in doc.ents:
    print(ent.text, "_", ent.label_)
# Out:
# Elon Musk _ PERSON
# the United States _ GPE

# %% [markdown]
# Spam Email Classification

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# Training data
texts = ["Free money now", "Hi how are you", "win cash prize", "Let's meet tomorrow"]
labels = [1, 0, 1, 0]   # 1 = Spam, 0 = Not Spam

# Convert text into numerical features
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts)

# Train model
model = MultinomialNB()
model.fit(X, labels)

# Test data
test = ["Free Prize"]
test_vec = vectorizer.transform(test)

# Prediction
prediction = model.predict(test_vec)

print("Prediction:", prediction)
if prediction[0] == 1:
    print("Spam Message")
else:
    print("Not Spam Message")
# Out:
# Prediction: [1]
# Spam Message

# %% [markdown]
# Cosine similarity

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

texts = ["I love ml", "i like ai and ml"]

vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform(texts)

similarity = cosine_similarity(tfidf[0:1], tfidf[1:2])

print("Similarity score:", similarity[0][0])
# Out:
# Similarity score: 0.22028815056182968

# %% [markdown]
# Minimum edit distance algorithm

# %%
import nltk
from nltk.metrics import edit_distance
word1="kitten"
word2="sitting"
distance=edit_distance(word1,word2)
print("word1:",word1)
print("word2",word2)
print("Edit distance:",distance)
# Out:
# word1: kitten
# word2 sitting
# Edit distance: 3

# %% [markdown]
# N gram model

# %%
from nltk.util import ngrams

sentence = "I Love NLP"
tokens = sentence.split()

bigrams = list(ngrams(tokens, 2))
print(bigrams)
# Out:
# [('I', 'Love'), ('Love', 'NLP')]

# %% [markdown]
# Stemming Algorithm

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
words = ["playing","played","plays"]
for w in words:
  print(ps.stem(w))
# Out:
# play
# play
# play
